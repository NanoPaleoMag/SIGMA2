# %% [markdown]
# # Import libraries

# %%
from umap import UMAP # for UMAP latent space projections
import sys # for relatove imports of sigma

# %% [markdown]
# Using relative imports for sigma and its packages whilst they are being redeveloped

# %%
sys.path.insert(0,"..")

from sigma.utils import normalisation as norm 
from sigma.utils import visualisation as visual
from sigma.utils.load import SEMDataset
from sigma.src.utils import same_seeds
from sigma.src.dim_reduction import Experiment
from sigma.models.autoencoder import AutoEncoder
from sigma.src.segmentation import PixelSegmenter
from sigma.gui import gui
from sigma.utils.loadtem import TEMDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 sys.path.insert(0,"..")
# ----> 3 from sigma.utils import normalisation as norm
#       4 from sigma.utils import visualisation as visual
#       5 from sigma.utils.load import SEMDataset
#
# File ~\Documents\PostDOc\Sigma2\SIGMA2\tutorials\..\sigma\utils\__init__.py:2
#       1 # -*- coding: utf-8 -*-
# ----> 2 from .load import SEMDataset
#       3 from .normalisation import (
#       4     neighbour_averaging,
#       5     zscore,
#       6     softmax,
#       7 )
#       9 from .visualisation import (
#      10     make_colormap,
#      11     plot_sum_spectrum,
#    (...)
#      15     plot_profile,
#      16     )
#
# File ~\Documents\PostDOc\Sigma2\SIGMA2\tutorials\..\sigma\utils\load.py:10
#       8 from os.path import isfile, join
#       9 from skimage.transform import resize
# ---> 10 from hyperspy._signals.eds_sem import EDSSEMSpectrum
#      11 from hyperspy._signals.signal2d import Signal2D
#      12 from .base import BaseDataset
#
# ModuleNotFoundError: No module named 'hyperspy._signals.eds_sem'

# %% [markdown]
# # Load files
#
# Load the image files from `chemical_maps_dir` and the intensity map file using the path `intensity_map_path`, creating an object of `IMAGEDataset`.

# %%
chemical_maps_dir='/'
intensity_map_path='.'
im = IMAGEDataset(chemical_maps_dir,intensity_map_path)

# %% [markdown]
# # Dataset preprocessing

# %%
gui.view_im_dataset(im)

# %% [markdown]
# ## Normalisation

# %%
im.rebin_signal(size=(4,4))

# %%
# Normalise the dataset using the (optional) sequential three methods.
im.normalisation([norm.neighbour_averaging,
                  norm.zscore])
                  # norm.softmax])

# %% [markdown]
# Use `gui.view_pixel_distributions` to view the intensity distributions after each sequential normalisation process.

# %%
gui.view_pixel_distributions(dataset=im, 
                             norm_list=[norm.neighbour_averaging,
                                        norm.zscore,
                                        norm.softmax], 
                             cmap='inferno')

# %% [markdown]
# ## (Optional) Assign RGB to elemental peaks

# %%
gui.view_rgb(im)

# %% [markdown]
# ## Check elemental distribution after normalisation

# %%
print('After normalisation:')
gui.view_intensity_maps(spectra=im.normalised_elemental_data, element_list=im.feature_list)

# %% [markdown]
# # 2. Dimensionality reduction

# %% [markdown]
# ## 2.2 Method 2: UMAP

# %%
from umap import UMAP

# Parameter tuning can be found https://umap-learn.readthedocs.io/en/latest/parameters.html
data = im.normalised_elemental_data.reshape(-1,len(im.feature_list))
umap = UMAP(
        n_neighbors=10,
        min_dist=0.1,
        n_components=2,
        metric='euclidean'
    )
latent = umap.fit_transform(data)

# %% [markdown]
# # 3. Pixel segmentation:

# %% [markdown]
# ## 3.2 Method 2: HDBSCAN clustering

# %%
# hyperparameter tuning can be found https://scikit-learn.org/stable/auto_examples/cluster/plot_hdbscan.html#hyperparameter-robustness
ps = PixelSegmenter(latent=latent, 
                    dataset=im,
                    method="HDBSCAN",
                    method_args=dict(min_cluster_size=50, min_samples=10,
                                     max_cluster_size=int(len(latent)/5),
                                     cluster_selection_epsilon=5e-2) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # hyperparameter tuning can be found https://scikit-learn.org/stable/auto_examples/cluster/plot_hdbscan.html#hyperparameter-robustness
# ----> 2 ps = PixelSegmenter(latent=latent,
#       3                     dataset=im,
#       4                     method="HDBSCAN",
#       5                     method_args=dict(min_cluster_size=50, min_samples=35,
#       6                                      max_cluster_size=int(len(latent)/5),
#       7                                      cluster_selection_epsilon=5e-2) )
#
# NameError: name 'PixelSegmenter' is not defined

# %% [markdown]
# ## Checking latent space

# %%
# Plot latent sapce (2-dimensional) with corresponding Gaussian models
gui.view_latent_space(ps=ps, color=True)

# %%
# visualise the latent space
gui.check_latent_space(ps=ps,ratio_to_be_shown=1.0, show_map=True)

# %%
# check the density of latent space
gui.plot_latent_density(ps=ps, bins=50)

# %% [markdown]
# ## Checking each clusters

# %%
gui.show_cluster_distribution(ps=ps)

# %% [markdown]
# ## Checking cluster map

# %%
# Plot phase map using the corresponding GM model
gui.view_phase_map(ps=ps)
